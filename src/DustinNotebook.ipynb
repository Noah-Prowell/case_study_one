# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/data.csv')
#df

# %%
def get_indicator_code(ind_name=''):
    '''
    if you dont give a value, then it will return a set of the Indicator Names.
    this is useful to look through the Indicator Names and pick the ones you want to find codes for.
    then, run this function again with the exact string needed to get its corresponding code'''
    if len(ind_name) == 0:
        return set(df_US.loc["Indicator Name"])
    else:
        '''
        Breakdown:
        df_US.cloumns gives us a pandas index of columns
        df_US == ind_name gives a boolean df where any value(s) == ind_name.
        then, .loc['Indicator Name'] gives us the Indicator Name row as a series, with the bools from df_US == ind_name as the values
        finally, the extra [0] slices out the Indicator Code value from the output series
        '''
        return df_US.columns[(df_US == ind_name).loc['Indicator Name']][0]

get_indicator_code('')
# Out:
# {'% of females ages 15-49 having comprehensive correct knowledge about HIV (2 prevent ways and reject 3 misconceptions)',
#  '% of males ages 15-49 having comprehensive correct knowledge about HIV (2 prevent ways and reject 3 misconceptions)',
#  'AIDS estimated deaths (UNAIDS estimates)',
#  'ARI treatment (% of children under 5 taken to a health provider)',
#  'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#  'Adults (ages 15+) and children (0-14 years) living with HIV',
#  'Adults (ages 15+) and children (ages 0-14) newly infected with HIV',
#  'Adults (ages 15+) living with HIV',
#  'Adults (ages 15+) newly infected with HIV',
#  'Age at first marriage, female',
#  'Age at first marriage, male',
#  'Age dependency ratio (% of working-age population)',
#  'Age dependency ratio, old',
#  'Age dependency ratio, young',
#  'Age population, age 0, female, interpolated',
#  'Age population, age 0, male, interpolated',
# ...

# %%
# grab just the US in a dataframe
df_US = df[df['Country Name'] == 'United States'].transpose()
df_US.columns = df_US.iloc[3]
df_US.drop(df_US.index[3])
# df_US
df_US.info
# Out:
# <bound method DataFrame.info of Indicator Code                                  SH.HIV.KNOW.FE.ZS  \
# Country Name                                        United States
# Country Code                                                  USA
# Indicator Name  % of females ages 15-49 having comprehensive c...
# Indicator Code                                  SH.HIV.KNOW.FE.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2012                                                          NaN
# 2013                                                          NaN
# 2014                                                          NaN
# 2015                                                          NaN
# Unnamed: 60                                                   NaN
#
# Indicator Code                                  SH.HIV.KNOW.MA.ZS  \
# Country Name                                        United States
# ...

# %%
# grab just the UK in a dataframe
df_UK = df[df['Country Name'] == 'United Kingdom'].transpose()
df_UK.columns = df_UK.iloc[3]
df_UK.drop(df_UK.index[3])
# df_UK
# Out:
# Indicator Code                                  SH.HIV.KNOW.FE.ZS  \
# Country Name                                       United Kingdom
# Country Code                                                  GBR
# Indicator Name  % of females ages 15-49 having comprehensive c...
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                          NaN
# 1963                                                          NaN
# 1964                                                          NaN
# 1965                                                          NaN
# 1966                                                          NaN
# 1967                                                          NaN
# 1968                                                          NaN
# 1969                                                          NaN
# ...

# %%
#getting just the two columns we want (for both data frames)
cols = ['SP.POP.TOTL', 'SP.DYN.CDRT.IN', 'SP.DYN.CBRT.IN']

new_df_UK = pd.DataFrame(df_UK[cols])
new_df_US = pd.DataFrame(df_US[cols])

new_df_US.columns = ['Population', 'Death', 'Birth Rate']
new_df_UK.columns = ['Population', 'Death', 'Birth Rate']

new_df_US
# Out:
#                        Population                                 Death  \
# Country Name        United States                         United States
# Country Code                  USA                                   USA
# Indicator Name  Population, total  Death rate, crude (per 1,000 people)
# Indicator Code        SP.POP.TOTL                        SP.DYN.CDRT.IN
# 1960                  1.80671e+08                                   9.5
# ...                           ...                                   ...
# 2012                  3.14103e+08                                   8.1
# 2013                  3.16427e+08                                   8.1
# 2014                  3.18907e+08                                   8.1
# 2015                  3.21419e+08                                   NaN
# Unnamed: 60                   NaN                                   NaN
#
#                                           Birth Rate
# ...

# %%
new_df_US.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, Country Name to Unnamed: 60
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Population      60 non-null     object
#  1   Death           59 non-null     object
#  2   Adult Literacy  59 non-null     object
# dtypes: object(3)
# memory usage: 4.4+ KB

# %%
merged_df = df_US_data.join(df_UK_data, lsuffix='_US', rsuffix='_UK')

#merged_df

# %%
# year_cols = [str(x) for x in list(range(1960, 2016))]
# messing_around = pd.melt(df, 
#                         id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'], 
#                         value_vars=year_cols)
# messing_around.rename(columns = {'variable':'Year'}, inplace = True) 
# messing_around.rename(columns = {'value':'Population'}, inplace = True) 
# messing_around.drop(['Indicator Code', 'Indicator Name'], axis=1, inplace=True)
# messing_around.sort_values(by=['Country Name', 'Year'])
# messing_around['Year'] = pd.to_numeric(messing_around['Year'])
# messing_around = messing_around[messing_around['Year']>=1985]

# messing_around

# %%
df_US_data = pd.DataFrame(df_UK[cols])[4:60]
df_UK_data = pd.DataFrame(df_US[cols])[4:60]
df_US_data.plot()
df_UK_data.plot()
# Out:
# <AxesSubplot:>

# %%
#slicing individual data segments for plotting

df_US_pop = new_df_US.iloc[4:60, 0:1]
df_UK_pop = new_df_UK.iloc[4:60, 0:1]

df_US_death = new_df_US.iloc[4:60, 1:2]
df_UK_death = new_df_UK.iloc[4:60, 1:2]

df_US_lit = new_df_US.iloc[4:60, 2:3]
df_UK_lit = new_df_UK.iloc[4:60, 2:3]

#df_UK_death
# Out:
#      Death
# 1960  11.5
# 1961    12
# 1962  11.9
# 1963  12.2
# 1964  11.3
# 1965  11.6
# 1966  11.8
# 1967  11.2
# 1968  11.9
# 1969  11.9
# 1970  11.8
# 1971  11.5
# 1972    12
# 1973  11.9
# 1974  11.9
# 1975  11.8
# 1976  12.1
# 1977  11.7
# 1978  11.9
# 1979    12
# 1980  11.7
# 1981  11.7
# 1982  11.8
# 1983  11.7
# 1984  11.4
# 1985  11.9
# 1986  11.7
# 1987  11.3
# 1988  11.4
# 1989  11.5
# 1990  11.2
# 1991  11.3
# 1992    11
# 1993  11.4
# 1994  10.8
# 1995  11.1
# 1996  10.9
# 1997  10.8
# 1998  10.8
# 1999  10.8
# 2000  10.3
# 2001  10.2
# 2002  10.2
# 2003  10.2
# 2004   9.7
# 2005   9.6
# 2006   9.4
# 2007   9.4
# 2008   9.4
# 2009     9
# 2010   8.9
# 2011   8.7
# 2012   8.9
# 2013     9
# 2014   8.8
# 2015   NaN

# %%
years = [x for x in range(1960, 2016)]

fig1, axs1 = plt.subplots(2,1, figsize=(10,4))

axs1[0].plot(years, df_US_pop)
axs1[0].set_title('US Population (hundreds of millions)')
#axs1[0].set_ybound(100000000,350000000)
#axs1[0].set_yticks([1,2,3,4],[100000000,200000000,300000000,400000000])

axs1[1].plot(years, df_UK_pop)
axs1[1].set_title('UK Population (tens of millions)')

plt.tight_layout()
plt.savefig('population.png')

# %%
fig2, axs2 = plt.subplots(2,1, figsize=(10,4))

axs2[0].plot(years, df_US_death, c='r')
axs2[0].set_title('US Death Rate (per 1,000 people)')

axs2[1].plot(years, df_UK_death, c='r')
axs2[1].set_title('UK Death Rate (per 1,000 people)')

plt.tight_layout()
plt.savefig('DeathRate.png')

# %%
fig3, axs3 = plt.subplots(2,1, figsize=(10,4))

axs3[0].plot(years, df_US_lit, c='g')
axs3[0].set_title('US Birth Rate (per 1,000 people)')

axs3[1].plot(years, df_UK_lit, c='g')
axs3[1].set_title('UK Birth Rate (per 1,000 people)')

plt.tight_layout()
plt.savefig('BirthRate.png')

# %%
axs3[0].scatter(years, df_US_death, c='r')
axs3[0].set_title('US Death')

axs3[1].scatter(years, df_UK_death, c='r')
axs3[1].set_title('UK Death')

plt.tight_layout()

# %%
merged_df = new_df_US.join(new_df_UK, lsuffix='_US', rsuffix='_UK')

# %%
merged_df.drop(merged_df.index[0:4], inplace=True)
merged_df.drop(merged_df.index[59:], inplace=True)
merged_df.drop(merged_df.iloc[1], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-273-3b071f5a1e78> in <module>
#       1 merged_df.drop(merged_df.index[0:4], inplace=True)
#       2 merged_df.drop(merged_df.index[59:], inplace=True)
# ----> 3 merged_df.drop(merged_df.iloc[1], inplace=True)
#
# ~/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4167             level=level,
#    4168             inplace=inplace,
# -> 4169             errors=errors,
#    4170         )
#    4171
#
# ~/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3882         for axis, labels in axes.items():
#    3883             if labels is not None:
# ...

# %%
merged_df
# Out:
#             Population_US Death_US Birth Rate_US Population_UK Death_UK  \
# 1964          1.91889e+08      9.4          21.1       5.4e+07     11.3
# 1965          1.94303e+08      9.4          19.4   5.43480e+07     11.6
# 1966           1.9656e+08      9.5          18.4   5.46485e+07     11.8
# 1967          1.98712e+08      9.4          17.8   5.49436e+07     11.2
# 1968          2.00706e+08      9.8          17.6   5.52117e+07     11.9
# 1969          2.02677e+08      9.5          17.9   5.54418e+07     11.9
# 1970          2.05052e+08      9.5          18.4   5.56632e+07     11.8
# 1971          2.07661e+08      9.3          17.2   5.58962e+07     11.5
# 1972          2.09896e+08      9.4          15.6   5.60861e+07       12
# 1973          2.11909e+08      9.3          14.8   5.61945e+07     11.9
# 1974          2.13854e+08      9.1          14.8     5.623e+07     11.9
# 1975          2.15973e+08      8.8          14.6   5.62258e+07     11.8
# ...

# %%
merged_df.hist(figsize=(5,5), bins=20);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-269-798a209da02c> in <module>
# ----> 1 merged_df.hist(figsize=(5,5), bins=20);
#
# ~/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     225         legend=legend,
#     226         bins=bins,
# --> 227         **kwargs,
#     228     )
#     229
#
# ~/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     413
#     414     if naxes == 0:
# --> 415         raise ValueError("hist method requires numerical columns, nothing to plot.")
#     416
#     417     fig, axes = _subplots(
# ...
