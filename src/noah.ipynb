# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7c420f77e480> in <module>
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 pwd
#
# NameError: name 'pwd' is not defined

# %%
pwd
# Out:
# '/home/noah/Galvanize/case-studies/case-study-1/src'

# %%
df = pd.read_csv('/home/noah/Galvanize/case-studies/case-study-1/data/data.csv')

# %%
# df_brit = health_df[health_df['Country Name'] == 'United Kingdom']
#df_brit.transpose()
# cols = ['SP.POP.TOTL', 'SP.DYN.CDRT.IN']
# df_brit_dr = pd.DataFrame(df_brit[cols])
# df_brit

# %%
df_hat_UK = df[df['Country Name'] == 'United Kingdom']
df_UK = df_hat_UK.transpose()
df_UK.columns = df_UK.iloc[3]
df_UK.drop(df_UK.index[3])
df_UK
# Out:
# Indicator Code                                  SH.HIV.KNOW.FE.ZS  \
# Country Name                                       United Kingdom
# Country Code                                                  GBR
# Indicator Name  % of females ages 15-49 having comprehensive c...
# Indicator Code                                  SH.HIV.KNOW.FE.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2012                                                          NaN
# 2013                                                          NaN
# 2014                                                          NaN
# 2015                                                          NaN
# Unnamed: 60                                                   NaN
#
# Indicator Code                                  SH.HIV.KNOW.MA.ZS  \
# Country Name                                       United Kingdom
# ...

# %%
cols = ['SP.POP.TOTL', 'SP.DYN.CDRT.IN']
new_df_UK = pd.DataFrame(df_UK[cols])
new_df_UK
# Out:
# Indicator Code        SP.POP.TOTL                        SP.DYN.CDRT.IN
# Country Name       United Kingdom                        United Kingdom
# Country Code                  GBR                                   GBR
# Indicator Name  Population, total  Death rate, crude (per 1,000 people)
# Indicator Code        SP.POP.TOTL                        SP.DYN.CDRT.IN
# 1960                     5.24e+07                                  11.5
# ...                           ...                                   ...
# 2012                  6.37003e+07                                   8.9
# 2013                  6.41282e+07                                     9
# 2014                  6.46132e+07                                   8.8
# 2015                  6.51382e+07                                   NaN
# Unnamed: 60                   NaN                                   NaN
#
# [61 rows x 2 columns]
