# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Increases the DPI of the plots, which makes them look better.
# %config InlineBackend.figure_format = 'retina'

# Changes the style of the plots.
# See documentation for examples of different styles: https://matplotlib.org/3.2.1/gallery/style_sheets/style_sheets_reference.html
plt.style.use('ggplot')

#read data
df = pd.read_csv('../data/data.csv')

#US dataframe
df_US = df[df['Country Name'] == 'United States'] #make US only Dataframe
columns = df_US.iloc[:,3] #make the colums the values for row 4 (indicator code) 
df_US = df_US[[column for column in df_US.columns if column not in ['Country Name', 'Country Code','Indicator Name','Indicator Code', 'Unnamed: 60']]].transpose()
df_US.index = df_US.index.astype(int)
df_US.columns = columns
df_US.index.name = 'Year'
# df_US.drop(df_US.index[3], inplace=True) #drop the indicator code row since its now the column name

#UK dataframe
df_UK = df[df['Country Name'] == 'United Kingdom']
columns = df_UK.iloc[:,3]
df_UK = df_UK[[column for column in df_UK.columns if column not in ['Country Name', 'Country Code','Indicator Name','Indicator Code', 'Unnamed: 60']]].transpose()
df_UK.index = df_UK.index.astype(int)
df_UK.columns = columns
df_UK.index.name = 'Year'
df_UK.head()
# Out:
# Indicator Code  SH.HIV.KNOW.FE.ZS  SH.HIV.KNOW.MA.ZS  SP.ADO.TFRT  \
# Year
# 1960                          NaN                NaN      84.7406
# 1961                          NaN                NaN      86.7628
# 1962                          NaN                NaN      88.7850
# 1963                          NaN                NaN      84.3684
# 1964                          NaN                NaN      79.9518
#
# Indicator Code  SH.HIV.TOTL  SH.HIV.INCD.TL  SH.DYN.AIDS  SH.HIV.INCD  \
# Year
# 1960                    NaN             NaN          NaN          NaN
# 1961                    NaN             NaN          NaN          NaN
# 1962                    NaN             NaN          NaN          NaN
# 1963                    NaN             NaN          NaN          NaN
# 1964                    NaN             NaN          NaN          NaN
#
# Indicator Code  SP.DYN.SMAM.FE  SP.DYN.SMAM.MA  SP.POP.DPND  ...  SP.URB.TOTL  \
# Year                                                         ...
# 1960                       NaN             NaN    53.609727  ...   41104656.0
# 1961                       NaN             NaN    54.168250  ...   41381472.0
# 1962                       NaN             NaN    54.377875  ...   41661202.0
# 1963                       NaN             NaN    54.416653  ...   41900114.0
# 1964                       NaN             NaN    54.570973  ...   42098400.0
#
# Indicator Code  SP.URB.TOTL.IN.ZS  SP.URB.GROW  SI.POV.URHC  SH.MLR.PREG.ZS  \
# Year
# 1960                       78.444     0.277314          NaN             NaN
# 1961                       78.374     0.671184          NaN             NaN
# 1962                       78.237     0.673704          NaN             NaN
# 1963                       78.099     0.571826          NaN             NaN
# 1964                       77.960     0.472119          NaN             NaN
#
# Indicator Code  SH.MLR.NETS.ZS  SH.MLR.SPF2.ZS  SN.ITK.VITA.ZS  SP.DYN.WFRT  \
# Year
# 1960                       NaN             NaN             NaN          NaN
# 1961                       NaN             NaN             NaN          NaN
# 1962                       NaN             NaN             NaN          NaN
# 1963                       NaN             NaN             NaN          NaN
# 1964                       NaN             NaN             NaN          NaN
#
# Indicator Code  SH.DYN.AIDS.FE.ZS
# Year
# 1960                          NaN
# 1961                          NaN
# 1962                          NaN
# 1963                          NaN
# 1964                          NaN
#
# [5 rows x 345 columns]

# %%
years = range(1960,2015,5)
fig, ax = plt.subplots(figsize = (10,5))
ax.plot(df_UK['SP.URB.TOTL.IN.ZS'][4:59], color = 'g', label = 'UK Urban Pop percent')
ax.plot(df_US['SP.URB.TOTL.IN.ZS'][4:59], color = 'b', label = 'US Urban Pop percent')
plt.title('US vs. UK of Urban Population as Percent of Population')
plt.xlabel('Years')
plt.ylabel('Percent of Population that is Urban')
plt.xticks(np.linspace(1960, 2015,11))
plt.legend()
plt.savefig('Urban_Pop_graph.png');

# %%
df_UK.index
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', 'Unnamed: 60'],
#       dtype='object')

# %%
    df.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  \
# 0  % of females ages 15-49 having comprehensive c...  SH.HIV.KNOW.FE.ZS
# 1  % of males ages 15-49 having comprehensive cor...  SH.HIV.KNOW.MA.ZS
# 2  Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 3  Adults (ages 15+) and children (0-14 years) li...        SH.HIV.TOTL
# 4  Adults (ages 15+) and children (ages 0-14) new...     SH.HIV.INCD.TL
#
#          1960        1961        1962        1963        1964        1965  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2  133.555013  134.159119  134.857912  134.504576  134.105211  133.569626
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    ...       2007       2008       2009       2010       2011       2012  \
# 0  ...        NaN        NaN        NaN        NaN        NaN        NaN
# 1  ...        NaN        NaN        NaN        NaN        NaN        NaN
# 2  ...  49.999851  49.887046  49.781207  49.672975  49.536047  49.383745
# 3  ...        NaN        NaN        NaN        NaN        NaN        NaN
# 4  ...        NaN        NaN        NaN        NaN        NaN        NaN
#
#         2013       2014  2015  Unnamed: 60
# 0        NaN        NaN   NaN          NaN
# 1        NaN        NaN   NaN          NaN
# 2  48.796558  48.196418   NaN          NaN
# 3        NaN        NaN   NaN          NaN
# 4        NaN        NaN   NaN          NaN
#
# [5 rows x 61 columns]
